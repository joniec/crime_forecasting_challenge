# %% [markdown]
# # Burglary
# ## Imports

# %%
import pandas as pd
import bokeh as bk
import matplotlib.pyplot as plt

plt.style.use('ggplot')
#from mpl_toolkits.basemap import Basemap

# %% [markdown]
# ## Opening data file

# %%
crimes = pd.read_csv("../../data/crimes.csv")

# %% [markdown]
# ## Keeping only burglary information

# %%
crimes = crimes[crimes['CATEGORY'] == 'BURGLARY'].drop('Unnamed: 0', axis=1)

# %%
crimes.head()
# Out:
#         CATEGORY  CALL GROUPS final_case_type  \
# 145993  BURGLARY   SUSPICIOUS          PROWLP
# 145994  BURGLARY   SUSPICIOUS          PROWLP
# 145995  BURGLARY   SUSPICIOUS          PROWLP
# 145996  BURGLARY   SUSPICIOUS          PROWLP
# 145997  BURGLARY   SUSPICIOUS          PROWLP
#
#                                                 CASE DESC    occ_date  \
# 145993  PROWLER                                       ...  2012-03-12
# 145994  PROWLER                                       ...  2012-03-15
# 145995  PROWLER                                       ...  2012-03-15
# 145996  PROWLER                                       ...  2012-03-20
# 145997  PROWLER                                       ...  2012-03-23
#
#         x_coordinate  y_coordinate  census_tract
# 145993       7688186      676342.0        9701.0
# 145994       7650823      670782.0         200.0
# 145995       7653382      698949.0        3602.0
# 145996       7648003      692938.0        2203.0
# 145997       7651256      684618.0        2100.0

# %% [markdown]
# # Getting unique values for features added to the model

# %%
crimes['CALL GROUPS'].unique()
# Out:
# array([' SUSPICIOUS', 'PROPERTY CRIME'], dtype=object)

# %%
crimes['final_case_type'].unique()
# Out:
# array(['PROWLP', 'BURGP '], dtype=object)

# %%
crimes['CASE DESC'].unique()
# Out:
# array(['PROWLER                                           ',
#        'BURGLARY - PRIORITY *H                            '], dtype=object)

# %%
# Drop case description as they map to final_case_type
crimes = crimes.drop('CASE DESC', axis=1)

# %%
crimes.head()
# Out:
#         CATEGORY  CALL GROUPS final_case_type    occ_date  x_coordinate  \
# 145993  BURGLARY   SUSPICIOUS          PROWLP  2012-03-12       7688186
# 145994  BURGLARY   SUSPICIOUS          PROWLP  2012-03-15       7650823
# 145995  BURGLARY   SUSPICIOUS          PROWLP  2012-03-15       7653382
# 145996  BURGLARY   SUSPICIOUS          PROWLP  2012-03-20       7648003
# 145997  BURGLARY   SUSPICIOUS          PROWLP  2012-03-23       7651256
#
#         y_coordinate  census_tract
# 145993      676342.0        9701.0
# 145994      670782.0         200.0
# 145995      698949.0        3602.0
# 145996      692938.0        2203.0
# 145997      684618.0        2100.0

# %% [markdown]
# ## Converting CALL GROUPS and final_case_type to numerical

# %%
dummies_call_groups = pd.get_dummies(crimes['CALL GROUPS'])
dummies_call_groups.head()
# Out:
#          SUSPICIOUS  PROPERTY CRIME
# 145993            1               0
# 145994            1               0
# 145995            1               0
# 145996            1               0
# 145997            1               0

# %%
dummies_final_case_type = pd.get_dummies(crimes['final_case_type'])
print(type(dummies_final_case_type))
dummies_final_case_type.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         BURGP   PROWLP
# 145993       0       1
# 145994       0       1
# 145995       0       1
# 145996       0       1
# 145997       0       1

# %% [markdown]
# # Preparing data to feed model

# %%
crimes_features = pd.concat([crimes.iloc[:,3:], dummies_final_case_type, dummies_call_groups], axis=1)

crimes_features.head()
# Out:
#           occ_date  x_coordinate  y_coordinate  census_tract  BURGP   PROWLP  \
# 145993  2012-03-12       7688186      676342.0        9701.0       0       1
# 145994  2012-03-15       7650823      670782.0         200.0       0       1
# 145995  2012-03-15       7653382      698949.0        3602.0       0       1
# 145996  2012-03-20       7648003      692938.0        2203.0       0       1
# 145997  2012-03-23       7651256      684618.0        2100.0       0       1
#
#          SUSPICIOUS  PROPERTY CRIME
# 145993            1               0
# 145994            1               0
# 145995            1               0
# 145996            1               0
# 145997            1               0

# %%
len(crimes_features['occ_date'].unique())
# Out:
# 1559

# %%
crimes_features.shape
# Out:
# (4671, 8)

# %%
# Adding date to index
crimes_features['occ_date'] = pd.to_datetime(crimes_features['occ_date'], format='%Y-%m-%d')
crimes_features.index = crimes_features['occ_date']

# %%
crimes_features = crimes_features.drop('occ_date',axis=1)

# %%
crimes_features.head(3)
# Out:
#             x_coordinate  y_coordinate  census_tract  BURGP   PROWLP  \
# occ_date
# 2012-03-12       7688186      676342.0        9701.0       0       1
# 2012-03-15       7650823      670782.0         200.0       0       1
# 2012-03-15       7653382      698949.0        3602.0       0       1
#
#              SUSPICIOUS  PROPERTY CRIME
# occ_date
# 2012-03-12            1               0
# 2012-03-15            1               0
# 2012-03-15            1               0

# %%
crimes_features_aggregated = crimes_features.groupby([pd.TimeGrouper("M"),'census_tract']).agg('count').iloc[:, 0].sort_values(ascending=False)

crimes_features_aggregated.head()
df_crimes_features_agg = crimes_features_aggregated.to_frame()
df_crimes_features_agg = df_crimes_features_agg.rename(columns = {'x_coordinate':'num_crimes'})
df_crimes_features_agg.head()
print(df_crimes_features_agg.columns.values)
# Out:
# ['num_crimes']

# %%
# Looking for a value
df_crimes_features_agg.loc[crimes_features_aggregated['cen'] == some_value]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\danielmateuspires\coding\crime_forecasting_challenge\venv\lib\site-packages\pandas\indexes\multi.py in get_value(self, series, key)
#     706             try:
# --> 707                 return _index.get_value_at(s, k)
#     708             except IndexError:
#
# pandas\index.pyx in pandas.index.get_value_at (pandas\index.c:2746)()
#
# pandas\src\util.pxd in util.get_value_at (pandas\index.c:16845)()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-142-d03ddae5ca03> in <module>()
#       1 # Looking for a value
# ----> 2 df_crimes_features_agg.loc[crimes_features_aggregated['cen'] == some_value]
#
# c:\users\danielmateuspires\coding\crime_forecasting_challenge\venv\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# c:\users\danielmateuspires\coding\crime_forecasting_challenge\venv\lib\site-packages\pandas\indexes\multi.py in get_value(self, series, key)
#     713                     raise InvalidIndexError(key)
#     714                 else:
# --> 715                     raise e1
#     716             except Exception:  # pragma: no cover
#     717                 raise e1
#
# c:\users\danielmateuspires\coding\crime_forecasting_challenge\venv\lib\site-packages\pandas\indexes\multi.py in get_value(self, series, key)
#     697
#     698         try:
# --> 699             return self._engine.get_value(s, k)
#     700         except KeyError as e1:
#     701             try:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_value (pandas\index.c:3567)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_value (pandas\index.c:3250)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4289)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13733)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13687)()
#
# KeyError: 'cen'

# %%
crimes_features.groupby(['census_tract']).agg('count').iloc[:, 0].sort_values(ascending=False)

# %% [markdown]
# # Evolution by date

# %%
# converting to date format
crimes['occ_date'] = pd.to_datetime(crimes['occ_date'], format='%Y-%m-%d')

# %%
# dropping coordinates
evolution = crimes[['CATEGORY','occ_date']]
evolution.head()
# Out:
#         CATEGORY   occ_date
# 145993  BURGLARY 2012-03-12
# 145994  BURGLARY 2012-03-15
# 145995  BURGLARY 2012-03-15
# 145996  BURGLARY 2012-03-20
# 145997  BURGLARY 2012-03-23

# %% [markdown]
# ## Sorting by date

# %%
# sorting by date
evolution = evolution.sort_values(by='occ_date')
evolution.head()
# Out:
#         CATEGORY   occ_date
# 146165  BURGLARY 2012-03-01
# 146217  BURGLARY 2012-03-02
# 146077  BURGLARY 2012-03-02
# 146166  BURGLARY 2012-03-02
# 146167  BURGLARY 2012-03-02

# %% [markdown]
# ### Adding date to index

# %%
evolution.index = evolution['occ_date']

# %% [markdown]
# ### Grouping by day

# %%
# grouping and counting crimes on each day
counts_day =evolution.groupby(['occ_date']).agg(['count'])
counts_day.head()
# Out:
#            CATEGORY
#               count
# occ_date
# 2012-03-01        1
# 2012-03-02        4
# 2012-03-03        2
# 2012-03-04        4
# 2012-03-05        1

# %% [markdown]
# ### Grouping by week

# %%
# grouping by week
counts_week = evolution.groupby(pd.TimeGrouper(freq='W')).agg(['count'])
counts_week = counts_week.drop('occ_date', axis=1)
counts_week.head()
# Out:
#            CATEGORY
#               count
# occ_date
# 2012-03-04       11
# 2012-03-11       14
# 2012-03-18       19
# 2012-03-25       19
# 2012-04-01       16

# %%
counts_week_pivot = pd.pivot_table(counts_week, index=counts_week.index.week, columns=counts_week.index.year, values='CATEGORY', aggfunc='sum')
counts_week_pivot = counts_week_pivot.fillna(counts_week_pivot.mean())
counts_week_pivot.head()
# Out:
#        count
#         2012  2013  2014  2015  2016
# 1  21.181818  19.0  28.0  16.0  19.0
# 2  21.181818  25.0  28.0  12.0  19.0
# 3  21.181818  19.0  23.0  13.0  12.0
# 4  21.181818  16.0  21.0  15.0  25.0
# 5  21.181818  18.0  14.0  21.0  13.0

# %%
counts_week_pivot.plot(figsize=(50,10))
plt.xticks([n for n in range(1,52)])
plt.savefig('../../plots/burglary_week_plot.png')
plt.show()

# %%
counts_week_april = evolution.loc[evolution.index.month == 4].groupby(pd.TimeGrouper(freq='D')).agg(['count'])
counts_week_april = counts_week_april.drop('occ_date', axis=1)
counts_week_april.head()
# Out:
#            CATEGORY
#               count
# occ_date
# 2012-04-01        2
# 2012-04-02        4
# 2012-04-03        2
# 2012-04-04        0
# 2012-04-05        0

# %%
counts_week_april_pivot = pd.pivot_table(counts_week_april, index=counts_week_april.index.day, columns=counts_week_april.index.year, values='CATEGORY', aggfunc='sum')
#counts_week_april_pivot = counts_week_april_pivot[13:17]
counts_week_april_pivot = counts_week_april_pivot.fillna(counts_week_april_pivot.mean())
counts_week_april_pivot.head()
# Out:
#   count
#    2012 2013 2014 2015 2016
# 1     2    2    2    8    1
# 2     4    3    1    0    0
# 3     2    3    2    5    3
# 4     0    2    0    3    4
# 5     0    1    6    5    6

# %% [markdown]
# ### Plotting mean for every year in April

# %%
#counts_week_april_pivot[:30].plot(figsize=(20,10))
#print(counts_week_april_pivot.mean(axis=1))
plt.plot(counts_week_april_pivot.mean(axis=1)[:30])
plt.xticks([n for n in range(1,31)])
plt.savefig('../../plots/burglary_week_april_plot.png')
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.plot(counts_week_pivot.mean(axis=1))
plt.xticks([n for n in range(1,52)])
plt.savefig('../../plots/burglary_week_mean_plot.png')
plt.show()

# %% [markdown]
# ## Plotting by day

# %%
counts_day.plot(figsize=(150,10))
plt.savefig('../../plots/burglary_day_plot.png')
plt.show()

# %% [markdown]
# ### Grouping by month

# %%
counts_month = evolution.groupby(pd.TimeGrouper(freq='M')).agg(['count'])

counts_month = counts_month.drop('occ_date', axis=1)
counts_month.head()
# Out:
#            CATEGORY
#               count
# occ_date
# 2012-03-31       77
# 2012-04-30       77
# 2012-05-31      114
# 2012-06-30       67
# 2012-07-31       95

# %% [markdown]
# ## Pivot transformation

# %%
counts_month_pivot = pd.pivot_table(counts_month, index=counts_month.index.month, columns=counts_month.index.year, values='CATEGORY', aggfunc='sum')
counts_month_pivot.head()
# Out:
#    count
#     2012  2013   2014  2015  2016
# 1    NaN  87.0  102.0  71.0  83.0
# 2    NaN  62.0   65.0  68.0  73.0
# 3   77.0  81.0  102.0  84.0  68.0
# 4   77.0  69.0   82.0  91.0  65.0
# 5  114.0  84.0   86.0  78.0  64.0

# %%
# Month numbers to literal
import calendar
counts_month_pivot = counts_month_pivot.rename(index=lambda x:  calendar.month_abbr[x])

# %%
# Modifying the legends
ax1 = counts_month_pivot.plot.bar(figsize=(20,10), use_index=True, grid=True, sort_columns=True)
lines, labels = ax1.get_legend_handles_labels()
print(labels)
new_labels = []
for l in labels:
    new_labels.append(l[8:len(l)-1])
print(new_labels)
ax1.legend(lines, new_labels, loc='best')  # improved legends

plt.savefig('../../plots/burglary_month_plot_barh.png')
plt.show()
# Out:
# ['(count, 2012)', '(count, 2013)', '(count, 2014)', '(count, 2015)', '(count, 2016)']
# ['2012', '2013', '2014', '2015', '2016']

# %%
# plot
ax2 = counts_month_pivot.plot(figsize=(20,10), use_index=True, grid=True)
ax2.legend(lines, new_labels, loc='best')  # improved legends
plt.savefig('../../plots/burglary_month_plot_line.png')
plt.show()

# %% [markdown]
# # Plotting in map

# %%
to_map = crimes[['CATEGORY','occ_date', 'x_coordinate', 'y_coordinate']]
to_map.head()
# Out:
#         CATEGORY   occ_date  x_coordinate  y_coordinate
# 145993  BURGLARY 2012-03-12       7688186      676342.0
# 145994  BURGLARY 2012-03-15       7650823      670782.0
# 145995  BURGLARY 2012-03-15       7653382      698949.0
# 145996  BURGLARY 2012-03-20       7648003      692938.0
# 145997  BURGLARY 2012-03-23       7651256      684618.0

# %%
to_map = to_map[(to_map['occ_date'] > '2015-01-01') & (to_map['occ_date'] < '2016-01-01')]
to_map.head()
# Out:
#         CATEGORY   occ_date  x_coordinate  y_coordinate
# 717007  BURGLARY 2015-01-02       7661948      698713.0
# 717008  BURGLARY 2015-01-07       7628635      711569.0
# 717009  BURGLARY 2015-02-05       7652267      681756.0
# 717010  BURGLARY 2015-02-06       7643842      709875.0
# 717011  BURGLARY 2015-02-08       7658599      688328.0

# %%
import shapefile as shp
import matplotlib.pyplot as plt

sf = shp.Reader("../../maps/Portland_Police_Districts.shp")

plt.figure()
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y)
plt.scatter(to_map['x_coordinate'], to_map['y_coordinate'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-54-9f7454b3d932> in <module>()
# ----> 1 import shapefile as shp
#       2 import matplotlib.pyplot as plt
#       3
#       4 sf = shp.Reader("../../maps/Portland_Police_Districts.shp")
#       5
#
# ImportError: No module named 'shapefile'
